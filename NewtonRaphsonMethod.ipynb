# %%
import pandas as pd
import numpy as np

# %%
####Newton Rhapson Method

###Define Function
def f(x):
  return ((-x/2) + ((x**2)/4 + 20/x)**0.5)

###Define Differential
def d_f(x):
  return ((x/2)-(20/(x**2)))/(2*((((x**2)/4)+(20/x))**0.5))


x = 10

d = {'x': [x], 'f(x)': [f(x)], "f'(x)": [d_f(x)]}
for i in range(1,60):
    p=x
    x = x +f(x) / d_f(x)
    d['x'].append(x)
    d['f(x)'].append(f(x))
    d["f'(x)"].append(d_f(x))
    if (x-p)<=0.01:
      break
    else:
      error=(x-p)/100
df = pd.DataFrame(d, columns=['x', 'f(x)', "f'(x)"])
df
col = list(df.columns)



df
# Out:
#             x      f(x)     f'(x)
# 0   10.000000  0.196152  0.461880
# 1   10.424682  0.180898  0.466167
# 2   10.812735  0.168440  0.469550
# 3   11.171462  0.158019  0.472294
# 4   11.506040  0.149137  0.474568
# 5   11.820298  0.141451  0.476486
# 6   12.117162  0.134718  0.478127
# 7   12.398924  0.128758  0.479548
# 8   12.667424  0.123436  0.480791
# 9   12.924159  0.118647  0.481888
# 10  13.170372  0.114309  0.482864
# 11  13.407104  0.110357  0.483738
# 12  13.635238  0.106738  0.484525
# 13  13.855532  0.103408  0.485238
# 14  14.068639  0.100332  0.485887
# 15  14.275132  0.097480  0.486481
# 16  14.475509  0.094826  0.487026
# 17  14.670213  0.092349  0.487527
# 18  14.859636  0.090031  0.487991
# 19  15.044129  0.087855  0.488421
# 20  15.224004  0.085809  0.488821
# 21  15.399546  0.083879  0.489194
# 22  15.571010  0.082057  0.489543
# 23  15.738629  0.080331  0.489869
# 24  15.902615  0.078695  0.490176
# 25  16.063160  0.077141  0.490464
# ...

# %%
x=10
xii=-5

count=0
def f(x):
  return((-x/2) + ((x**2)/4 + 20/x)**0.5)

def dif(x):
  return ((x/2)-(20/(x**2)))/(2*((((x**2)/4)+(20/x))**0.5))
if count!=0:
  while (xii-x)/100 <-0.01:
    xii=x+(f(x)/dif(x))
    x=xii    
    count=+1
else:
  count=+1

# %%
x=[1,2,3]
type(x)
# Out:
# list

# %%
xii
# Out:
# -5
